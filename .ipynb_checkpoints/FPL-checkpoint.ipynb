# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from lxml import html
import re

# %%
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

# %%
r = requests.get(url)
json = r.json()

# %%
json['elements']
# Out:
# [{'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 58822,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Cédric',
#   'form': '0.0',
#   'id': 1,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '58822.jpg',
#   'points_per_game': '2.3',
#   'second_name': 'Alves Soares',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 48,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '10.7',
#   'web_name': 'Cédric',
#   'minutes': 1481,
#   'goals_scored': 1,
#   'assists': 1,
#   'clean_sheets': 3,
#   'goals_conceded': 27,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 3,
#   'bps': 292,
#   'influence': '318.4',
#   'creativity': '327.1',
#   'threat': '111.0',
#   'ict_index': '75.8',
#   'influence_rank': 205,
#   'influence_rank_type': 81,
#   'creativity_rank': 114,
#   'creativity_rank_type': 24,
#   'threat_rank': 239,
#   'threat_rank_type': 80,
#   'ict_index_rank': 199,
#   'ict_index_rank_type': 63,
#   'corners_and_indirect_freekicks_order': 2,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 3,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 80201,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '2.7',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Bernd',
#   'form': '0.0',
#   'id': 2,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '80201.jpg',
#   'points_per_game': '2.5',
#   'second_name': 'Leno',
#   'selected_by_percent': '0.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 10,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '2.2',
#   'web_name': 'Leno',
#   'minutes': 360,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 9,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 10,
#   'bonus': 0,
#   'bps': 69,
#   'influence': '85.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '8.5',
#   'influence_rank': 322,
#   'influence_rank_type': 23,
#   'creativity_rank': 411,
#   'creativity_rank_type': 37,
#   'threat_rank': 397,
#   'threat_rank_type': 27,
#   'ict_index_rank': 346,
#   'ict_index_rank_type': 24,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 84450,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Granit',
#   'form': '0.0',
#   'id': 3,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '84450.jpg',
#   'points_per_game': '2.2',
#   'second_name': 'Xhaka',
#   'selected_by_percent': '0.5',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 60,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '12.0',
#   'web_name': 'Xhaka',
#   'minutes': 2327,
#   'goals_scored': 1,
#   'assists': 2,
#   'clean_sheets': 6,
#   'goals_conceded': 38,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 10,
#   'red_cards': 1,
#   'saves': 0,
#   'bonus': 3,
#   'bps': 334,
#   'influence': '395.4',
#   'creativity': '522.9',
#   'threat': '262.0',
#   'ict_index': '118.2',
#   'influence_rank': 164,
#   'influence_rank_type': 62,
#   'creativity_rank': 55,
#   'creativity_rank_type': 40,
#   'threat_rank': 148,
#   'threat_rank_type': 85,
#   'ict_index_rank': 102,
#   'ict_index_rank_type': 63,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 153256,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Mohamed',
#   'form': '0.0',
#   'id': 4,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '153256.jpg',
#   'points_per_game': '1.9',
#   'second_name': 'Elneny',
#   'selected_by_percent': '1.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 27,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '6.0',
#   'web_name': 'Elneny',
#   'minutes': 801,
#   'goals_scored': 0,
#   'assists': 2,
#   'clean_sheets': 0,
#   'goals_conceded': 17,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 156,
#   'influence': '163.2',
#   'creativity': '131.5',
#   'threat': '49.0',
#   'ict_index': '34.4',
#   'influence_rank': 284,
#   'influence_rank_type': 119,
#   'creativity_rank': 217,
#   'creativity_rank_type': 125,
#   'threat_rank': 291,
#   'threat_rank_type': 145,
#   'ict_index_rank': 286,
#   'ict_index_rank_type': 130,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 156074,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Rob',
#   'form': '0.0',
#   'id': 5,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '156074.jpg',
#   'points_per_game': '1.9',
#   'second_name': 'Holding',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 29,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '6.4',
#   'web_name': 'Holding',
#   'minutes': 840,
#   'goals_scored': 1,
#   'assists': 0,
#   'clean_sheets': 2,
#   'goals_conceded': 16,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 1,
#   'saves': 0,
#   'bonus': 2,
#   'bps': 152,
#   'influence': '253.0',
#   'creativity': '8.6',
#   'threat': '49.0',
#   'ict_index': '31.1',
#   'influence_rank': 233,
#   'influence_rank_type': 91,
#   'creativity_rank': 342,
#   'creativity_rank_type': 133,
#   'threat_rank': 292,
#   'threat_rank_type': 112,
#   'ict_index_rank': 295,
#   'ict_index_rank_type': 107,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 167199,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Thomas',
#   'form': '0.0',
#   'id': 6,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '167199.jpg',
#   'points_per_game': '3.0',
#   'second_name': 'Partey',
#   'selected_by_percent': '0.5',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 71,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '14.2',
#   'web_name': 'Partey',
#   'minutes': 2027,
#   'goals_scored': 2,
#   'assists': 2,
#   'clean_sheets': 10,
#   'goals_conceded': 25,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 6,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 4,
#   'bps': 345,
#   'influence': '359.6',
#   'creativity': '275.5',
#   'threat': '394.0',
#   'ict_index': '103.0',
#   'influence_rank': 184,
#   'influence_rank_type': 72,
#   'creativity_rank': 134,
#   'creativity_rank_type': 87,
#   'threat_rank': 100,
#   'threat_rank_type': 60,
#   'ict_index_rank': 132,
#   'ict_index_rank_type': 76,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 4,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 184029,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.8',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Martin',
#   'form': '0.0',
#   'id': 7,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 65,
#   'photo': '184029.jpg',
#   'points_per_game': '3.6',
#   'second_name': 'Ødegaard',
#   'selected_by_percent': '12.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 131,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '20.2',
#   'web_name': 'Ødegaard',
#   'minutes': 2782,
#   'goals_scored': 7,
#   'assists': 4,
#   'clean_sheets': 11,
#   'goals_conceded': 39,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 9,
#   'bps': 541,
#   'influence': '676.6',
#   'creativity': '1073.2',
#   'threat': '639.0',
#   'ict_index': '238.2',
#   'influence_rank': 54,
#   'influence_rank_type': 20,
#   'creativity_rank': 5,
#   'creativity_rank_type': 4,
#   'threat_rank': 47,
#   'threat_rank_type': 28,
#   'ict_index_rank': 21,
#   'ict_index_rank_type': 13,
#   'corners_and_indirect_freekicks_order': 3,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 1,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 192895,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.8',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Kieran',
#   'form': '0.0',
#   'id': 8,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '192895.jpg',
#   'points_per_game': '4.8',
#   'second_name': 'Tierney',
#   'selected_by_percent': '2.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 106,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '21.2',
#   'web_name': 'Tierney',
#   'minutes': 1916,
#   'goals_scored': 1,
#   'assists': 3,
#   'clean_sheets': 11,
#   'goals_conceded': 21,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 11,
#   'bps': 454,
#   'influence': '365.2',
#   'creativity': '335.9',
#   'threat': '198.0',
#   'ict_index': '90.1',
#   'influence_rank': 179,
#   'influence_rank_type': 77,
#   'creativity_rank': 108,
#   'creativity_rank_type': 22,
#   'threat_rank': 184,
#   'threat_rank_type': 50,
#   'ict_index_rank': 170,
#   'ict_index_rank_type': 49,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 195735,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Nicolas',
#   'form': '0.0',
#   'id': 9,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '195735.jpg',
#   'points_per_game': '2.2',
#   'second_name': 'Pépé',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 45,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '8.2',
#   'web_name': 'Pépé',
#   'minutes': 681,
#   'goals_scored': 1,
#   'assists': 4,
#   'clean_sheets': 2,
#   'goals_conceded': 9,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 1,
#   'bps': 127,
#   'influence': '149.4',
#   'creativity': '216.9',
#   'threat': '400.0',
#   'ict_index': '76.3',
#   'influence_rank': 293,
#   'influence_rank_type': 125,
#   'creativity_rank': 161,
#   'creativity_rank_type': 100,
#   'threat_rank': 98,
#   'threat_rank_type': 58,
#   'ict_index_rank': 197,
#   'ict_index_rank_type': 98,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 2,
#   'direct_freekicks_text': '',
#   'penalties_order': 3,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 198869,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Benjamin',
#   'form': '0.0',
#   'id': 10,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '198869.jpg',
#   'points_per_game': '3.3',
#   'second_name': 'White',
#   'selected_by_percent': '7.5',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 107,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '23.8',
#   'web_name': 'White',
#   'minutes': 2880,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 13,
#   'goals_conceded': 35,
#   'own_goals': 1,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 9,
#   'bps': 557,
#   'influence': '592.8',
#   'creativity': '182.3',
#   'threat': '150.0',
#   'ict_index': '92.5',
#   'influence_rank': 78,
#   'influence_rank_type': 29,
#   'creativity_rank': 178,
#   'creativity_rank_type': 50,
#   'threat_rank': 206,
#   'threat_rank_type': 64,
#   'ict_index_rank': 160,
#   'ict_index_rank_type': 47,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 205533,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '2.7',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Eddie',
#   'form': '0.0',
#   'id': 11,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 70,
#   'photo': '205533.jpg',
#   'points_per_game': '2.6',
#   'second_name': 'Nketiah',
#   'selected_by_percent': '1.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 55,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '7.9',
#   'web_name': 'Nketiah',
#   'minutes': 823,
#   'goals_scored': 5,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 18,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 6,
#   'bps': 194,
#   'influence': '249.2',
#   'creativity': '165.2',
#   'threat': '408.0',
#   'ict_index': '82.1',
#   'influence_rank': 237,
#   'influence_rank_type': 27,
#   'creativity_rank': 190,
#   'creativity_rank_type': 24,
#   'threat_rank': 95,
#   'threat_rank_type': 29,
#   'ict_index_rank': 181,
#   'ict_index_rank_type': 29,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 209289,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.6',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Emile',
#   'form': '0.0',
#   'id': 12,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 60,
#   'photo': '209289.jpg',
#   'points_per_game': '3.8',
#   'second_name': 'Smith Rowe',
#   'selected_by_percent': '3.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 125,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '20.8',
#   'web_name': 'Smith Rowe',
#   'minutes': 1909,
#   'goals_scored': 10,
#   'assists': 2,
#   'clean_sheets': 8,
#   'goals_conceded': 28,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 9,
#   'bps': 435,
#   'influence': '555.8',
#   'creativity': '453.3',
#   'threat': '576.0',
#   'ict_index': '158.4',
#   'influence_rank': 98,
#   'influence_rank_type': 34,
#   'creativity_rank': 74,
#   'creativity_rank_type': 53,
#   'threat_rank': 54,
#   'threat_rank_type': 33,
#   'ict_index_rank': 56,
#   'ict_index_rank_type': 37,
#   'corners_and_indirect_freekicks_order': 5,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 223340,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '3.2',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Bukayo',
#   'form': '0.0',
#   'id': 13,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 80,
#   'photo': '223340.jpg',
#   'points_per_game': '4.7',
#   'second_name': 'Saka',
#   'selected_by_percent': '20.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 179,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '22.4',
#   'web_name': 'Saka',
#   'minutes': 2978,
#   'goals_scored': 11,
#   'assists': 9,
#   'clean_sheets': 13,
#   'goals_conceded': 39,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 6,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 18,
#   'bps': 566,
#   'influence': '790.4',
#   'creativity': '977.8',
#   'threat': '1434.0',
#   'ict_index': '320.0',
#   'influence_rank': 23,
#   'influence_rank_type': 9,
#   'creativity_rank': 7,
#   'creativity_rank_type': 6,
#   'threat_rank': 4,
#   'threat_rank_type': 2,
#   'ict_index_rank': 4,
#   'ict_index_rank_type': 3,
#   'corners_and_indirect_freekicks_order': 1,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 1,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 223723,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Takehiro',
#   'form': '0.0',
#   'id': 14,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '223723.jpg',
#   'points_per_game': '3.6',
#   'second_name': 'Tomiyasu',
#   'selected_by_percent': '7.9',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 75,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '16.7',
#   'web_name': 'Tomiyasu',
#   'minutes': 1680,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 9,
#   'goals_conceded': 20,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 5,
#   'bps': 344,
#   'influence': '312.4',
#   'creativity': '240.9',
#   'threat': '110.0',
#   'ict_index': '66.4',
#   'influence_rank': 207,
#   'influence_rank_type': 82,
#   'creativity_rank': 150,
#   'creativity_rank_type': 37,
#   'threat_rank': 242,
#   'threat_rank_type': 83,
#   'ict_index_rank': 224,
#   'ict_index_rank_type': 78,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 225321,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '3.6',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Aaron',
#   'form': '0.0',
#   'id': 15,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '225321.jpg',
#   'points_per_game': '4.0',
#   'second_name': 'Ramsdale',
#   'selected_by_percent': '11.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 135,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '27.0',
#   'web_name': 'Ramsdale',
#   'minutes': 3060,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 12,
#   'goals_conceded': 39,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 90,
#   'bonus': 14,
#   'bps': 641,
#   'influence': '690.2',
#   'creativity': '1.0',
#   'threat': '0.0',
#   'ict_index': '69.0',
#   'influence_rank': 52,
#   'influence_rank_type': 12,
#   'creativity_rank': 358,
#   'creativity_rank_type': 12,
#   'threat_rank': 491,
#   'threat_rank_type': 48,
#   'ict_index_rank': 218,
#   'ict_index_rank_type': 12,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 226597,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.8',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Gabriel',
#   'form': '0.0',
#   'id': 16,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '226597.jpg',
#   'points_per_game': '4.2',
#   'second_name': 'dos Santos Magalhães',
#   'selected_by_percent': '8.5',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 146,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '29.2',
#   'web_name': 'Gabriel',
#   'minutes': 3063,
#   'goals_scored': 5,
#   'assists': 0,
#   'clean_sheets': 13,
#   'goals_conceded': 38,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 6,
#   'red_cards': 1,
#   'saves': 0,
#   'bonus': 16,
#   'bps': 682,
#   'influence': '746.8',
#   'creativity': '131.6',
#   'threat': '470.0',
#   'ict_index': '134.7',
#   'influence_rank': 32,
#   'influence_rank_type': 8,
#   'creativity_rank': 216,
#   'creativity_rank_type': 65,
#   'threat_rank': 75,
#   'threat_rank_type': 7,
#   'ict_index_rank': 73,
#   'ict_index_rank_type': 12,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 437626,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Nuno',
#   'form': '0.0',
#   'id': 17,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '437626.jpg',
#   'points_per_game': '2.2',
#   'second_name': 'Varela Tavares',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 49,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '10.9',
#   'web_name': 'Tavares',
#   'minutes': 1169,
#   'goals_scored': 1,
#   'assists': 1,
#   'clean_sheets': 3,
#   'goals_conceded': 19,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 2,
#   'bps': 199,
#   'influence': '201.0',
#   'creativity': '188.2',
#   'threat': '221.0',
#   'ict_index': '61.1',
#   'influence_rank': 259,
#   'influence_rank_type': 103,
#   'creativity_rank': 176,
#   'creativity_rank_type': 48,
#   'threat_rank': 165,
#   'threat_rank_type': 42,
#   'ict_index_rank': 233,
#   'ict_index_rank_type': 83,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 437742,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Albert',
#   'form': '0.0',
#   'id': 18,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '437742.jpg',
#   'points_per_game': '1.7',
#   'second_name': 'Sambi Lokonga',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 32,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '7.1',
#   'web_name': 'Sambi',
#   'minutes': 1129,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 7,
#   'goals_conceded': 11,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 5,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 173,
#   'influence': '192.4',
#   'creativity': '263.4',
#   'threat': '108.0',
#   'ict_index': '56.3',
#   'influence_rank': 264,
#   'influence_rank_type': 110,
#   'creativity_rank': 139,
#   'creativity_rank_type': 90,
#   'threat_rank': 245,
#   'threat_rank_type': 127,
#   'ict_index_rank': 242,
#   'ict_index_rank_type': 109,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 444145,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.6',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Gabriel',
#   'form': '0.0',
#   'id': 19,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 60,
#   'photo': '444145.jpg',
#   'points_per_game': '3.8',
#   'second_name': 'Martinelli Silva',
#   'selected_by_percent': '16.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 110,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '18.3',
#   'web_name': 'Martinelli',
#   'minutes': 1855,
#   'goals_scored': 6,
#   'assists': 7,
#   'clean_sheets': 7,
#   'goals_conceded': 25,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 1,
#   'saves': 0,
#   'bonus': 6,
#   'bps': 345,
#   'influence': '475.8',
#   'creativity': '483.3',
#   'threat': '786.0',
#   'ict_index': '174.7',
#   'influence_rank': 121,
#   'influence_rank_type': 49,
#   'creativity_rank': 65,
#   'creativity_rank_type': 47,
#   'threat_rank': 32,
#   'threat_rank_type': 20,
#   'ict_index_rank': 46,
#   'ict_index_rank_type': 32,
#   'corners_and_indirect_freekicks_order': 4,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 5,
#   'direct_freekicks_text': '',
#   'penalties_order': 2,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 92371,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Pablo',
#   'form': '0.0',
#   'id': 20,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '92371.jpg',
#   'points_per_game': '0.5',
#   'second_name': 'Marí Villar',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.2',
#   'web_name': 'Pablo Marí',
#   'minutes': 180,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 35,
#   'influence': '55.4',
#   'creativity': '12.3',
#   'threat': '11.0',
#   'ict_index': '7.9',
#   'influence_rank': 333,
#   'influence_rank_type': 130,
#   'creativity_rank': 333,
#   'creativity_rank_type': 131,
#   'threat_rank': 321,
#   'threat_rank_type': 129,
#   'ict_index_rank': 349,
#   'ict_index_rank_type': 132,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 154043,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Ainsley',
#   'form': '0.0',
#   'id': 21,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '154043.jpg',
#   'points_per_game': '1.5',
#   'second_name': 'Maitland-Niles',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 12,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '2.4',
#   'web_name': 'Maitland-Niles',
#   'minutes': 263,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 2,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 44,
#   'influence': '42.6',
#   'creativity': '41.3',
#   'threat': '9.0',
#   'ict_index': '9.3',
#   'influence_rank': 346,
#   'influence_rank_type': 152,
#   'creativity_rank': 294,
#   'creativity_rank_type': 146,
#   'threat_rank': 323,
#   'threat_rank_type': 156,
#   'ict_index_rank': 343,
#   'ict_index_rank_type': 155,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 198849,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Lucas',
#   'form': '0.0',
#   'id': 22,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '198849.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Torreira di Pascua',
#   'selected_by_percent': '0.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Torreira',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 439,
#   'influence_rank_type': 178,
#   'creativity_rank': 436,
#   'creativity_rank_type': 180,
#   'threat_rank': 426,
#   'threat_rank_type': 178,
#   'ict_index_rank': 442,
#   'ict_index_rank_type': 179,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 200641,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Reiss',
#   'form': '0.0',
#   'id': 23,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '200641.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Nelson',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.2',
#   'web_name': 'Nelson',
#   'minutes': 19,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 4,
#   'influence': '4.0',
#   'creativity': '11.6',
#   'threat': '20.0',
#   'ict_index': '3.6',
#   'influence_rank': 379,
#   'influence_rank_type': 167,
#   'creativity_rank': 335,
#   'creativity_rank_type': 160,
#   'threat_rank': 313,
#   'threat_rank_type': 154,
#   'ict_index_rank': 363,
#   'ict_index_rank_type': 161,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 224068,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Matt',
#   'form': '0.0',
#   'id': 24,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '224068.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Turner',
#   'selected_by_percent': '0.9',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Turner',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 402,
#   'influence_rank_type': 43,
#   'creativity_rank': 393,
#   'creativity_rank_type': 33,
#   'threat_rank': 377,
#   'threat_rank_type': 21,
#   'ict_index_rank': 404,
#   'ict_index_rank_type': 43,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 438098,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.6',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Fábio',
#   'form': '0.0',
#   'id': 25,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 60,
#   'photo': '438098.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Ferreira Vieira',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Fábio Vieira',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 528,
#   'influence_rank_type': 226,
#   'creativity_rank': 528,
#   'creativity_rank_type': 226,
#   'threat_rank': 528,
#   'threat_rank_type': 226,
#   'ict_index_rank': 528,
#   'ict_index_rank_type': 226,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 462424,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'William',
#   'form': '0.0',
#   'id': 26,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '462424.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Saliba',
#   'selected_by_percent': '1.5',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Saliba',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 467,
#   'influence_rank_type': 188,
#   'creativity_rank': 463,
#   'creativity_rank_type': 188,
#   'threat_rank': 455,
#   'threat_rank_type': 188,
#   'ict_index_rank': 469,
#   'ict_index_rank_type': 188,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 479683,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Marcus',
#   'form': '0.0',
#   'id': 27,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '479683.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Oliveira Alencar',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Marquinhos',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 505,
#   'influence_rank_type': 212,
#   'creativity_rank': 505,
#   'creativity_rank_type': 213,
#   'threat_rank': 502,
#   'threat_rank_type': 213,
#   'ict_index_rank': 506,
#   'ict_index_rank_type': 213,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 205651,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '3.1',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Gabriel',
#   'form': '0.0',
#   'id': 28,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 80,
#   'photo': '205651.jpg',
#   'points_per_game': '4.3',
#   'second_name': 'Fernando de Jesus',
#   'selected_by_percent': '69.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 120,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '15.0',
#   'web_name': 'Jesus',
#   'minutes': 1871,
#   'goals_scored': 8,
#   'assists': 8,
#   'clean_sheets': 11,
#   'goals_conceded': 15,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 16,
#   'bps': 488,
#   'influence': '567.4',
#   'creativity': '530.9',
#   'threat': '1126.0',
#   'ict_index': '222.3',
#   'influence_rank': 92,
#   'influence_rank_type': 9,
#   'creativity_rank': 51,
#   'creativity_rank_type': 5,
#   'threat_rank': 12,
#   'threat_rank_type': 7,
#   'ict_index_rank': 25,
#   'ict_index_rank_type': 7,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 206325,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.8',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Oleksandr',
#   'form': '0.0',
#   'id': 313,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '206325.jpg',
#   'points_per_game': '3.9',
#   'second_name': 'Zinchenko',
#   'selected_by_percent': '12.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 59,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '11.8',
#   'web_name': 'Zinchenko',
#   'minutes': 1044,
#   'goals_scored': 0,
#   'assists': 4,
#   'clean_sheets': 5,
#   'goals_conceded': 9,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 4,
#   'bps': 284,
#   'influence': '259.4',
#   'creativity': '282.1',
#   'threat': '111.0',
#   'ict_index': '65.4',
#   'influence_rank': 228,
#   'influence_rank_type': 89,
#   'creativity_rank': 131,
#   'creativity_rank_type': 33,
#   'threat_rank': 241,
#   'threat_rank_type': 82,
#   'ict_index_rank': 227,
#   'ict_index_rank_type': 81,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 84583,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.9',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Philippe',
#   'form': '0.0',
#   'id': 29,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 70,
#   'photo': '84583.jpg',
#   'points_per_game': '4.4',
#   'second_name': 'Coutinho Correia',
#   'selected_by_percent': '18.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 2,
#   'team_code': 7,
#   'total_points': 83,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '11.9',
#   'web_name': 'Coutinho',
#   'minutes': 1327,
#   'goals_scored': 5,
#   'assists': 3,
#   'clean_sheets': 7,
#   'goals_conceded': 17,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 7,
#   'bps': 283,
#   'influence': '360.8',
#   'creativity': '349.3',
#   'threat': '445.0',
#   'ict_index': '115.7',
#   'influence_rank': 183,
# ...
#   'first_name': 'Rayan',
#   'form': '0.0',
#   'id': 487,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '448514.jpg',
#   'points_per_game': '3.8',
#   'second_name': 'Aït-Nouri',
#   'selected_by_percent': '2.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 87,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '19.3',
#   'web_name': 'Aït-Nouri',
#   'minutes': 1826,
#   'goals_scored': 1,
#   'assists': 4,
#   'clean_sheets': 7,
#   'goals_conceded': 26,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 10,
#   'bps': 367,
#   'influence': '390.8',
#   'creativity': '323.2',
#   'threat': '174.0',
#   'ict_index': '89.1',
#   'influence_rank': 168,
#   'influence_rank_type': 71,
#   'creativity_rank': 118,
#   'creativity_rank_type': 26,
#   'threat_rank': 198,
#   'threat_rank_type': 60,
#   'ict_index_rank': 171,
#   'ict_index_rank_type': 50,
#   'corners_and_indirect_freekicks_order': 3,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': None,
#   'code': 449988,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '0.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Fabio',
#   'form': '0.0',
#   'id': 488,
#   'in_dreamteam': False,
#   'news': 'Joined Anderlecht on loan - Expected back 01 Jul',
#   'news_added': '2022-07-19T23:00:04.338024Z',
#   'now_cost': 55,
#   'photo': '449988.jpg',
#   'points_per_game': '1.4',
#   'second_name': 'Silva',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 30,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '5.5',
#   'web_name': 'Fabio Silva',
#   'minutes': 562,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 43,
#   'influence': '21.0',
#   'creativity': '48.3',
#   'threat': '262.0',
#   'ict_index': '32.0',
#   'influence_rank': 360,
#   'influence_rank_type': 35,
#   'creativity_rank': 285,
#   'creativity_rank_type': 34,
#   'threat_rank': 149,
#   'threat_rank_type': 33,
#   'ict_index_rank': 293,
#   'ict_index_rank_type': 33,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 510362,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Toti António',
#   'form': '0.0',
#   'id': 489,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '510362.jpg',
#   'points_per_game': '1.5',
#   'second_name': 'Gomes',
#   'selected_by_percent': '0.9',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 6,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '1.5',
#   'web_name': 'Toti',
#   'minutes': 360,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 6,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 52,
#   'influence': '87.0',
#   'creativity': '4.5',
#   'threat': '28.0',
#   'ict_index': '12.0',
#   'influence_rank': 320,
#   'influence_rank_type': 127,
#   'creativity_rank': 347,
#   'creativity_rank_type': 136,
#   'threat_rank': 306,
#   'threat_rank_type': 120,
#   'ict_index_rank': 334,
#   'ict_index_rank_type': 129,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': None,
#   'code': 510363,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Francisco Jorge',
#   'form': '0.0',
#   'id': 490,
#   'in_dreamteam': False,
#   'news': 'Knee injury - Expected back 07 Jan',
#   'news_added': '2022-07-11T11:30:03.644676Z',
#   'now_cost': 50,
#   'photo': '510363.jpg',
#   'points_per_game': '2.5',
#   'second_name': 'Tomás Oliveira',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'i',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 20,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '4.0',
#   'web_name': 'Chiquinho',
#   'minutes': 203,
#   'goals_scored': 0,
#   'assists': 3,
#   'clean_sheets': 0,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 2,
#   'bps': 67,
#   'influence': '99.4',
#   'creativity': '83.4',
#   'threat': '118.0',
#   'ict_index': '30.1',
#   'influence_rank': 313,
#   'influence_rank_type': 136,
#   'creativity_rank': 252,
#   'creativity_rank_type': 139,
#   'threat_rank': 236,
#   'threat_rank_type': 124,
#   'ict_index_rank': 298,
#   'ict_index_rank_type': 138,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 159533,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Adama',
#   'form': '0.0',
#   'id': 491,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '159533.jpg',
#   'points_per_game': '2.2',
#   'second_name': 'Traoré Diarra',
#   'selected_by_percent': '0.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 44,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '8.0',
#   'web_name': 'Adama',
#   'minutes': 1069,
#   'goals_scored': 1,
#   'assists': 1,
#   'clean_sheets': 5,
#   'goals_conceded': 10,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 168,
#   'influence': '192.0',
#   'creativity': '271.1',
#   'threat': '300.0',
#   'ict_index': '76.6',
#   'influence_rank': 265,
#   'influence_rank_type': 111,
#   'creativity_rank': 135,
#   'creativity_rank_type': 88,
#   'threat_rank': 127,
#   'threat_rank_type': 74,
#   'ict_index_rank': 196,
#   'ict_index_rank_type': 97,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 216208,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Matija',
#   'form': '0.0',
#   'id': 492,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '216208.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Šarkić',
#   'selected_by_percent': '3.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Šarkić',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 400,
#   'influence_rank_type': 42,
#   'creativity_rank': 390,
#   'creativity_rank_type': 31,
#   'threat_rank': 374,
#   'threat_rank_type': 19,
#   'ict_index_rank': 402,
#   'ict_index_rank_type': 42,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 222531,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Morgan',
#   'form': '0.0',
#   'id': 493,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '222531.jpg',
#   'points_per_game': '0.5',
#   'second_name': 'Gibbs-White',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 1,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.2',
#   'web_name': 'Gibbs-White',
#   'minutes': 7,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.7',
#   'threat': '24.0',
#   'ict_index': '2.1',
#   'influence_rank': 516,
#   'influence_rank_type': 220,
#   'creativity_rank': 363,
#   'creativity_rank_type': 169,
#   'threat_rank': 309,
#   'threat_rank_type': 151,
#   'ict_index_rank': 373,
#   'ict_index_rank_type': 164,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 501837,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.5',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Yerson',
#   'form': '0.0',
#   'id': 494,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '501837.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Mosquera Valdelamar',
#   'selected_by_percent': '1.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Mosquera',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'influence_rank': 412,
#   'influence_rank_type': 159,
#   'creativity_rank': 404,
#   'creativity_rank_type': 159,
#   'threat_rank': 388,
#   'threat_rank_type': 159,
#   'ict_index_rank': 415,
#   'ict_index_rank_type': 159,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 19624,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.0',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'João Filipe Iria',
#   'form': '0.0',
#   'id': 503,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '19624.jpg',
#   'points_per_game': '2.7',
#   'second_name': 'Santos Moutinho',
#   'selected_by_percent': '2.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 96,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '19.2',
#   'web_name': 'Moutinho',
#   'minutes': 2970,
#   'goals_scored': 2,
#   'assists': 1,
#   'clean_sheets': 11,
#   'goals_conceded': 40,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 8,
#   'bps': 511,
#   'influence': '527.8',
#   'creativity': '660.9',
#   'threat': '144.0',
#   'ict_index': '133.2',
#   'influence_rank': 105,
#   'influence_rank_type': 40,
#   'creativity_rank': 28,
#   'creativity_rank_type': 20,
#   'threat_rank': 210,
#   'threat_rank_type': 111,
#   'ict_index_rank': 74,
#   'ict_index_rank_type': 47,
#   'corners_and_indirect_freekicks_order': 1,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 1,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 432830,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.3',
#   'ep_this': None,
#   'event_points': 0,
#   'first_name': 'Nathan',
#   'form': '0.0',
#   'id': 516,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '432830.jpg',
#   'points_per_game': '2.9',
#   'second_name': 'Collins',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 55,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 0,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '12.2',
#   'web_name': 'Collins',
#   'minutes': 1670,
#   'goals_scored': 2,
#   'assists': 0,
#   'clean_sheets': 5,
#   'goals_conceded': 26,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 1,
#   'saves': 0,
#   'bonus': 1,
#   'bps': 272,
#   'influence': '436.0',
#   'creativity': '78.2',
#   'threat': '254.0',
#   'ict_index': '77.0',
#   'influence_rank': 140,
#   'influence_rank_type': 56,
#   'creativity_rank': 255,
#   'creativity_rank_type': 85,
#   'threat_rank': 151,
#   'threat_rank_type': 32,
#   'ict_index_rank': 193,
#   'ict_index_rank_type': 60,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': ''}]

# %%
players = pd.DataFrame(json['elements'])
players[['id', 'web_name', 'team', 'element_type','total_points','now_cost']].head()
# Out:
#    id web_name  team  element_type  total_points  now_cost
# 0   1   Cédric     1             2            48        45
# 1   2     Leno     1             1            10        45
# 2   3    Xhaka     1             3            60        50
# 3   4   Elneny     1             3            27        45
# 4   5  Holding     1             2            29        45

# %%
position = np.array([json['element_types'][i]['singular_name_short'] for i in range(4)])

# %%
position
# Out:
# array(['GKP', 'DEF', 'MID', 'FWD'], dtype='<U3')

# %%
pos = players['element_type'].values

# %%
pos_word = position[pos-1]

# %%
players['element_type'] = pos_word

# %%
players[['id', 'web_name', 'team', 'element_type','total_points','now_cost']].head()
# Out:
#    id web_name  team element_type  total_points  now_cost
# 0   1   Cédric     1          DEF            48        45
# 1   2     Leno     1          GKP            10        45
# 2   3    Xhaka     1          MID            60        50
# 3   4   Elneny     1          MID            27        45
# 4   5  Holding     1          DEF            29        45

# %%
players['ppc'] = players['total_points']/players['now_cost']

# %%
players = players.sort_values('ppc', ascending=False)

# %%
players = players[['web_name', 'team', 'element_type','total_points','now_cost','ppc']]

# %%
teams = np.array([json['teams'][i]['name'] for i in range(len(json['teams']))])

# %%
team_ids = players['team'].values

# %%
team_word = teams[team_ids-1]

# %%
players['team'] = team_word

# %%
GKPs = players[players['element_type']=='GKP']
DEFs = players[players['element_type']=='DEF']
MIDs = players[players['element_type']=='MID']
FWDs = players[players['element_type']=='FWD']

# %%
GKPs
# Out:
#          web_name            team element_type  total_points  now_cost  \
# 300       Alisson       Liverpool          GKP           176        55
# 515            Sá          Wolves          GKP           146        50
# 458        Lloris           Spurs          GKP           158        55
# 329       Ederson        Man City          GKP           155        55
# 119       Sánchez        Brighton          GKP           126        45
# 490     Fabianski        West Ham          GKP           136        50
# 14       Ramsdale         Arsenal          GKP           135        50
# 160        Guaita  Crystal Palace          GKP           119        45
# 348        De Gea         Man Utd          GKP           132        50
# 238    Schmeichel       Leicester          GKP           131        50
# 153         Mendy         Chelsea          GKP           130        50
# 399          Pope       Newcastle          GKP           130        50
# 31       Martínez     Aston Villa          GKP           129        50
# 194      Pickford         Everton          GKP           116        45
# 281       Meslier           Leeds          GKP           106        45
# 378      Dubravka       Newcastle          GKP            96        45
# 83           Raya       Brentford          GKP            95        45
# 459       Forster           Spurs          GKP            57        40
# 432      McCarthy     Southampton          GKP            55        45
# 170       Butland  Crystal Palace          GKP            30        45
# 376        Darlow       Newcastle          GKP            20        40
# 139  Arrizabalaga         Chelsea          GKP            19        45
# 188       Begović         Everton          GKP            13        40
# 1            Leno         Arsenal          GKP            10        45
# 308      Kelleher       Liverpool          GKP             8        40
# 332       Steffen        Man City          GKP             7        40
# 426     Hennessey   Nott'm Forest          GKP             4        40
# 244          Ward       Leicester          GKP             3        40
# 108        Steele        Brighton          GKP             2        40
# 455     Caballero     Southampton          GKP             2        40
# 279      Klaesson           Leeds          GKP             2        40
# 508        Areola        West Ham          GKP             2        45
# 35          Olsen     Aston Villa          GKP             1        40
# 221     Gazzaniga          Fulham          GKP             0        40
# 368        Heaton         Man Utd          GKP             0        40
# 406         Samba   Nott'm Forest          GKP             0        45
# 452           Lis     Southampton          GKP             0        40
# 453        Bazunu     Southampton          GKP             0        45
# 422     Henderson   Nott'm Forest          GKP             0        45
# 105     Strakosha       Brentford          GKP             0        45
# 102      Balcombe       Brentford          GKP             0        40
# 484        Austin           Spurs          GKP             0        40
# 23         Turner         Arsenal          GKP             0        40
# 529        Šarkić          Wolves          GKP             0        40
# 344        Ortega        Man City          GKP             0        40
# 73        Travers     Bournemouth          GKP             0        45
# 78         Dennis     Bournemouth          GKP             0        40
# 227         Rodák          Fulham          GKP             0        45
# 184      Matthews  Crystal Palace          GKP             0        40
# 183     Johnstone  Crystal Palace          GKP             0        45
# 346        Carson        Man City          GKP             0        40
# 317        Adrián       Liverpool          GKP             0        40
#
#           ppc
# 300  3.200000
# 515  2.920000
# 458  2.872727
# 329  2.818182
# 119  2.800000
# 490  2.720000
# 14   2.700000
# 160  2.644444
# 348  2.640000
# 238  2.620000
# 153  2.600000
# 399  2.600000
# 31   2.580000
# 194  2.577778
# 281  2.355556
# 378  2.133333
# 83   2.111111
# 459  1.425000
# 432  1.222222
# 170  0.666667
# 376  0.500000
# 139  0.422222
# 188  0.325000
# 1    0.222222
# 308  0.200000
# 332  0.175000
# 426  0.100000
# 244  0.075000
# 108  0.050000
# 455  0.050000
# 279  0.050000
# 508  0.044444
# 35   0.025000
# 221  0.000000
# 368  0.000000
# 406  0.000000
# 452  0.000000
# 453  0.000000
# 422  0.000000
# 105  0.000000
# 102  0.000000
# 484  0.000000
# 23   0.000000
# 529  0.000000
# 344  0.000000
# 73   0.000000
# 78   0.000000
# 227  0.000000
# 184  0.000000
# 183  0.000000
# 346  0.000000
# 317  0.000000

# %%
DEFs
# Out:
#      web_name         team element_type  total_points  now_cost       ppc
# 43       Cash  Aston Villa          DEF           147        50  2.940000
# 15    Gabriel      Arsenal          DEF           146        50  2.920000
# 328   Cancelo     Man City          DEF           201        70  2.871429
# 295     Matip    Liverpool          DEF           170        60  2.833333
# 299  Van Dijk    Liverpool          DEF           183        65  2.815385
# ..        ...          ...          ...           ...       ...       ...
# 488   Lenglet        Spurs          DEF             0        50  0.000000
# 489    Spence        Spurs          DEF             0        45  0.000000
# 507    Aguerd     West Ham          DEF             0        50  0.000000
# 66     Stacey  Bournemouth          DEF             0        45  0.000000
# 316    Ramsay    Liverpool          DEF             0        40  0.000000
#
# [196 rows x 6 columns]

# %%
MIDs
# Out:
#         web_name         team element_type  total_points  now_cost       ppc
# 438  Ward-Prowse  Southampton          MID           159        65  2.446154
# 500        Bowen     West Ham          MID           206        85  2.423529
# 154    Gallagher      Chelsea          MID           140        60  2.333333
# 499     Benrahma     West Ham          MID           138        60  2.300000
# 251     Maddison    Leicester          MID           181        80  2.262500
# ..           ...          ...          ...           ...       ...       ...
# 292   Sinisterra        Leeds          MID             0        65  0.000000
# 314     Carvalho    Liverpool          MID             0        55  0.000000
# 64     Marcondes  Bournemouth          MID             0        50  0.000000
# 65         Lerma  Bournemouth          MID             0        50  0.000000
# 509       Downes     West Ham          MID             0        45  0.000000
#
# [227 rows x 6 columns]

# %%
FWDs
# Out:
#           web_name            team element_type  total_points  now_cost  \
# 82           Toney       Brentford          FWD           139        70
# 97          Mbeumo       Brentford          FWD           119        60
# 307     Diogo Jota       Liverpool          FWD           175        90
# 493        Antonio        West Ham          FWD           140        75
# 40         Watkins     Aston Villa          FWD           131        75
# 156          Broja         Chelsea          FWD            92        55
# 460           Kane           Spurs          FWD           192       115
# 442          Adams     Southampton          FWD           103        65
# 174        Edouard  Crystal Palace          FWD            87        55
# 377           Wood       Newcastle          FWD            91        60
# 30            Ings     Aston Villa          FWD           106        70
# 347        Ronaldo         Man Utd          FWD           159       105
# 116         Maupay        Brighton          FWD            98        65
# 27           Jesus         Arsenal          FWD           120        80
# 487    Richarlison           Spurs          FWD           125        85
# 513        Jiménez          Wolves          FWD           101        70
# 245          Vardy       Leicester          FWD           133        95
# 151        Havertz         Chelsea          FWD           112        80
# 109        Welbeck        Brighton          FWD            89        65
# 252      Iheanacho       Leicester          FWD            80        65
# 261           Daka       Leicester          FWD            70        60
# 176         Mateta  Crystal Palace          FWD            61        55
# 163        Benteke  Crystal Palace          FWD            58        55
# 439    A.Armstrong     Southampton          FWD            57        55
# 379         Wilson       Newcastle          FWD            75        75
# 203  Calvert-Lewin         Everton          FWD            64        80
# 10         Nketiah         Arsenal          FWD            55        70
# 285       Gelhardt           Leeds          FWD            43        55
# 298        Firmino       Liverpool          FWD            62        80
# 143         Werner         Chelsea          FWD            62        80
# 189         Rondón         Everton          FWD            30        50
# 525    Fabio Silva          Wolves          FWD            30        55
# 270        Bamford           Leeds          FWD            28        75
# 280      Greenwood           Leeds          FWD            15        45
# 99           Forss       Brentford          FWD            11        45
# 366        Martial         Man Utd          FWD            14        70
# 384          Gayle       Newcastle          FWD             7        45
# 54          Archer     Aston Villa          FWD             3        45
# 343          Delap        Man City          FWD             1        45
# 480       Scarlett           Spurs          FWD             1        45
# 52           Davis     Aston Villa          FWD             1        55
# 224       Mitrović          Fulham          FWD             0        65
# 404         Taylor   Nott'm Forest          FWD             0        45
# 129          Undav        Brighton          FWD             0        55
# 232          Muniz          Fulham          FWD             0        55
# 421        Awoniyi   Nott'm Forest          FWD             0        60
# 233     Stansfield          Fulham          FWD             0        45
# 418        Johnson   Nott'm Forest          FWD             0        60
# 131         Enciso        Brighton          FWD             0        50
# 415       Surridge   Nott'm Forest          FWD             0        50
# 339        Haaland        Man City          FWD             0       115
# 486        Parrott           Spurs          FWD             0        45
# 340        Álvarez        Man City          FWD             0        65
# 185         Plange  Crystal Palace          FWD             0        45
# 67         Solanke     Bournemouth          FWD             0        60
# 315         Darwin       Liverpool          FWD             0        90
# 63           Moore     Bournemouth          FWD             0        55
# 510       Scamacca        West Ham          FWD             0        70
# 457           Mara     Southampton          FWD             0        55
#
#           ppc
# 82   1.985714
# 97   1.983333
# 307  1.944444
# 493  1.866667
# 40   1.746667
# 156  1.672727
# 460  1.669565
# 442  1.584615
# 174  1.581818
# 377  1.516667
# 30   1.514286
# 347  1.514286
# 116  1.507692
# 27   1.500000
# 487  1.470588
# 513  1.442857
# 245  1.400000
# 151  1.400000
# 109  1.369231
# 252  1.230769
# 261  1.166667
# 176  1.109091
# 163  1.054545
# 439  1.036364
# 379  1.000000
# 203  0.800000
# 10   0.785714
# 285  0.781818
# 298  0.775000
# 143  0.775000
# 189  0.600000
# 525  0.545455
# 270  0.373333
# 280  0.333333
# 99   0.244444
# 366  0.200000
# 384  0.155556
# 54   0.066667
# 343  0.022222
# 480  0.022222
# 52   0.018182
# 224  0.000000
# 404  0.000000
# 129  0.000000
# 232  0.000000
# 421  0.000000
# 233  0.000000
# 418  0.000000
# 131  0.000000
# 415  0.000000
# 339  0.000000
# 486  0.000000
# 340  0.000000
# 185  0.000000
# 67   0.000000
# 315  0.000000
# 63   0.000000
# 510  0.000000
# 457  0.000000

# %%
writer = pd.ExcelWriter('FPL_Data.xlsx')
GKPs.to_excel(writer,'Goalkeepers')
DEFs.to_excel(writer,'Defenders')
MIDs.to_excel(writer,'Midfielders')
FWDs.to_excel(writer,'Forwards')
writer.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 writer = pd.ExcelWriter('FPL_Data.xlsx')
#       2 GKPs.to_excel(writer,'Goalkeepers')
#       3 DEFs.to_excel(writer,'Defenders')
#
# File ~/opt/anaconda3/envs/soccer/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py:49, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      36 def __init__(
#      37     self,
#      38     path,
#    (...)
#      47 ):
#      48     # Use the openpyxl module as the Excel writer.
# ---> 49     from openpyxl.workbook import Workbook
#      51     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      53     super().__init__(
#      54         path,
#      55         mode=mode,
#    (...)
#      58         engine_kwargs=engine_kwargs,
#      59     )
#
# ModuleNotFoundError: No module named 'openpyxl'
